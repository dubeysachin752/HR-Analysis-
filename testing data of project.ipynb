# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
test_df=pd.read_csv('test.csv')
test_df.head()
# Out:
#    Id  Age BusinessTravel              Department  DistanceFromHome  \
# 0   1   28  Travel_Rarely  Research & Development                 9
# 1   2   31  Travel_Rarely                   Sales                 6
# 2   3   37  Travel_Rarely  Research & Development                 6
# 3   4   42  Travel_Rarely  Research & Development                 1
# 4   5   45     Non-Travel  Research & Development                 4
#
#    Education EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0          3        Medical             377                        4    Male
# 1          4        Medical             653                        1    Male
# 2          3        Medical             474                        3    Male
# 3          2  Life Sciences             827                        4  Female
# 4          2  Life Sciences             972                        3    Male
#
#    ...  PerformanceRating StockOptionLevel  TotalWorkingYears  \
# 0  ...                  4                1                  5
# 1  ...                  4                2                 13
# 2  ...                  3                2                 13
# 3  ...                  3                1                  8
# 4  ...                  3                0                  9
#
#   TrainingTimesLastYear  YearsAtCompany  YearsInCurrentRole  \
# 0                     3               5                   2
# 1                     4               7                   7
# 2                     2               7                   7
# 3                     4               4                   3
# 4                     5               9                   7
#
#   YearsSinceLastPromotion  YearsWithCurrManager  CommunicationSkill  Behaviour
# 0                       0                     4                   5          1
# 1                       5                     7                   3          1
# 2                       6                     7                   4          1
# 3                       0                     2                   5          1
# 4                       0                     8                   2          1
#
# [5 rows x 28 columns]

# %%
test_df.isnull().sum()
# Out:
# Id                         0
# Age                        0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeNumber             0
# EnvironmentSatisfaction    0
# Gender                     0
# JobInvolvement             0
# JobRole                    0
# JobSatisfaction            0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# OverTime                   0
# PercentSalaryHike          0
# PerformanceRating          0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsInCurrentRole         0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# CommunicationSkill         0
# Behaviour                  0
# dtype: int64

# %%
test_df['BusinessTravel'].value_counts()
# Out:
# Travel_Rarely        334
# Travel_Frequently     78
# Non-Travel            58
# Name: BusinessTravel, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# creating instance of labelencoder
labelencoder = LabelEncoder()

# %%
test_df['BusinessTravel'] = labelencoder.fit_transform(test_df['BusinessTravel'])
test_df['Department'] = labelencoder.fit_transform(test_df['Department'])
test_df['EducationField'] = labelencoder.fit_transform(test_df['EducationField'])
test_df['Gender'] = labelencoder.fit_transform(test_df['Gender'])
test_df['JobRole'] = labelencoder.fit_transform(test_df['JobRole'])
test_df['OverTime'] = labelencoder.fit_transform(test_df['OverTime'])
test_df['MaritalStatus'] = labelencoder.fit_transform(test_df['MaritalStatus'])

# %%
test_df.shape
# Out:
# (470, 28)

# %%
test_df.drop(['EmployeeNumber'],axis=1)
test_df.drop(['MaritalStatus'],axis=1)
test_df.drop(['Behaviour'],axis=1)
test_df.drop(['Id'],axis=1)
test_df.drop(['YearsWithCurrManager'],axis=1)
# Out:
#       Id  Age  BusinessTravel  Department  DistanceFromHome  Education  \
# 0      1   28               2           1                 9          3
# 1      2   31               2           2                 6          4
# 2      3   37               2           1                 6          3
# 3      4   42               2           1                 1          2
# 4      5   45               0           1                 4          2
# ..   ...  ...             ...         ...               ...        ...
# 465  466   32               2           1                 2          4
# 466  467   18               1           2                 3          2
# 467  468   24               2           1                23          3
# 468  469   31               2           1                23          3
# 469  470   36               2           1                 5          4
#
#      EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  ...  \
# 0                 3             377                        4       1  ...
# 1                 3             653                        1       1  ...
# 2                 3             474                        3       1  ...
# 3                 1             827                        4       0  ...
# 4                 1             972                        3       1  ...
# ..              ...             ...                      ...     ...  ...
# 465               1            1692                        4       1  ...
# 466               3            1624                        2       0  ...
# 467               3             639                        2       1  ...
# 468               3             367                        2       1  ...
# 469               1            1651                        2       0  ...
#
#      PercentSalaryHike  PerformanceRating  StockOptionLevel  \
# 0                   23                  4                 1
# 1                   22                  4                 2
# 2                   13                  3                 2
# 3                   13                  3                 1
# 4                   12                  3                 0
# ..                 ...                ...               ...
# 465                 12                  3                 0
# 466                 12                  3                 0
# 467                 11                  3                 2
# 468                 21                  4                 1
# 469                 12                  3                 2
#
#      TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 0                    5                      3               5
# 1                   13                      4               7
# 2                   13                      2               7
# 3                    8                      4               4
# 4                    9                      5               9
# ..                 ...                    ...             ...
# 465                  1                      2               1
# 466                  0                      2               0
# 467                  6                      3               6
# 468                 10                      2               9
# 469                  9                      6               3
#
#      YearsInCurrentRole  YearsSinceLastPromotion  CommunicationSkill  \
# 0                     2                        0                   5
# 1                     7                        5                   3
# 2                     7                        6                   4
# 3                     3                        0                   5
# 4                     7                        0                   2
# ..                  ...                      ...                 ...
# 465                   0                        0                   5
# 466                   0                        0                   2
# 467                   5                        1                   1
# 468                   0                        7                   3
# 469                   2                        0                   5
#
#      Behaviour
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ..         ...
# 465          1
# 466          1
# 467          1
# 468          1
# 469          1
#
# [470 rows x 27 columns]

# %%
test_df.dtypes
# Out:
# Id                         int64
# Age                        int64
# BusinessTravel             int32
# Department                 int32
# DistanceFromHome           int64
# Education                  int64
# EducationField             int32
# EmployeeNumber             int64
# EnvironmentSatisfaction    int64
# Gender                     int32
# JobInvolvement             int64
# JobRole                    int32
# JobSatisfaction            int64
# MaritalStatus              int32
# MonthlyIncome              int64
# NumCompaniesWorked         int64
# OverTime                   int32
# PercentSalaryHike          int64
# PerformanceRating          int64
# StockOptionLevel           int64
# TotalWorkingYears          int64
# TrainingTimesLastYear      int64
# YearsAtCompany             int64
# YearsInCurrentRole         int64
# YearsSinceLastPromotion    int64
# YearsWithCurrManager       int64
# CommunicationSkill         int64
# Behaviour                  int64
# dtype: object

# %%
test_df
# Out:
#       Id  Age  BusinessTravel  Department  DistanceFromHome  Education  \
# 0      1   28               2           1                 9          3
# 1      2   31               2           2                 6          4
# 2      3   37               2           1                 6          3
# 3      4   42               2           1                 1          2
# 4      5   45               0           1                 4          2
# ..   ...  ...             ...         ...               ...        ...
# 465  466   32               2           1                 2          4
# 466  467   18               1           2                 3          2
# 467  468   24               2           1                23          3
# 468  469   31               2           1                23          3
# 469  470   36               2           1                 5          4
#
#      EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  ...  \
# 0                 3             377                        4       1  ...
# 1                 3             653                        1       1  ...
# 2                 3             474                        3       1  ...
# 3                 1             827                        4       0  ...
# 4                 1             972                        3       1  ...
# ..              ...             ...                      ...     ...  ...
# 465               1            1692                        4       1  ...
# 466               3            1624                        2       0  ...
# 467               3             639                        2       1  ...
# 468               3             367                        2       1  ...
# 469               1            1651                        2       0  ...
#
#      PerformanceRating  StockOptionLevel  TotalWorkingYears  \
# 0                    4                 1                  5
# 1                    4                 2                 13
# 2                    3                 2                 13
# 3                    3                 1                  8
# 4                    3                 0                  9
# ..                 ...               ...                ...
# 465                  3                 0                  1
# 466                  3                 0                  0
# 467                  3                 2                  6
# 468                  4                 1                 10
# 469                  3                 2                  9
#
#      TrainingTimesLastYear  YearsAtCompany  YearsInCurrentRole  \
# 0                        3               5                   2
# 1                        4               7                   7
# 2                        2               7                   7
# 3                        4               4                   3
# 4                        5               9                   7
# ..                     ...             ...                 ...
# 465                      2               1                   0
# 466                      2               0                   0
# 467                      3               6                   5
# 468                      2               9                   0
# 469                      6               3                   2
#
#      YearsSinceLastPromotion  YearsWithCurrManager  CommunicationSkill  \
# 0                          0                     4                   5
# 1                          5                     7                   3
# 2                          6                     7                   4
# 3                          0                     2                   5
# 4                          0                     8                   2
# ..                       ...                   ...                 ...
# 465                        0                     0                   5
# 466                        0                     0                   2
# 467                        1                     4                   1
# 468                        7                     8                   3
# 469                        0                     2                   5
#
#      Behaviour
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ..         ...
# 465          1
# 466          1
# 467          1
# 468          1
# 469          1
#
# [470 rows x 28 columns]

# %%
test_df.to_csv('formulatedtest.csv',index=False)

# %%
df_Test.fillna(df_Test.mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-b1ee87d367c2> in <module>
# ----> 1 df_Test.fillna(df_Test.mean())
#
# NameError: name 'df_Test' is not defined
